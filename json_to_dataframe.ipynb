# %% [markdown]
# # JSON to Pandas Dataframe

# %%
import pandas as pd
import json
import os

# Specify the directory containing your JSON files
json_dir = "./"

# Initialize an empty list to store DataFrames
dataframes = []

# Iterate through each file in the directory
for filename in os.listdir(json_dir):
    if filename.endswith(".json"):  # Process only JSON files
        file_path = os.path.join(json_dir, filename)
        try:
            # Load the JSON file
            with open(file_path, 'r') as f:
                data = json.load(f)
            
            # Ensure the JSON data is a list of dictionaries
            if isinstance(data, list):
                # Convert the JSON data to a DataFrame
                df = pd.DataFrame(data)
                df['Paperid'] = os.path.splitext(filename)[0]
                dataframes.append(df)  # Add the DataFrame to the list
            else:
                print(f"File {filename} does not contain a list of dictionaries.")
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON in file {filename}: {e}")

# Combine all DataFrames into a single DataFrame
if dataframes:
    combined_df = pd.concat(dataframes, ignore_index=True)
    print("Combined DataFrame:")
    print(combined_df)
else:
    print("No valid JSON data found.")
# Out:
# Combined DataFrame:
#                           name                 nominal_composition  \
# 0     CoCrFe0.75NiMo0.3Nb0.125              Co24Cr24Fe18Ni24Mo7Nb3
# 1                     10HEA-Ni                  (CoCrFeNiMn)90Hf10
# 2                     20HEA-Ni                  (CoCrFeNiMn)90Hf10
# 3                     30HEA-Ni                  (CoCrFeNiMn)90Hf10
# 4              Al17Ni34Ti17V32                     Al17Ni34Ti17V32
# ...                        ...                                 ...
# 4647                CoCrFeMnNi      Co20.0Cr20.0Fe20.0Mn20.0Ni20.0
# 4648             CoCrFeMnNi-2N  Co19.6Cr19.6Fe19.6Mn19.6Ni19.6N2.0
# 4649                CoCrFeMnNi           Co1.0Cr1.0Fe1.0Mn1.0Ni1.0
# 4650             Al0.3CoCrFeNi           Al0.3Co1.0Cr1.0Fe1.0Ni1.0
# 4651              Al0.1CrNbVMo            Al0.1Cr1.0Nb1.0V1.0Mo1.0
#
#                      measured_composition lattice_constant    phases  \
# 0     Co25Cr21.3Fe18Ni23.5Mo7Nb3Si1.4W0.8            3.605     FCC,σ
# 1                               Not found           3.5207       FCC
# 2                               Not found           3.5207       FCC
# 3                               Not found           3.5207       FCC
# 4                               Not found            0.591   L21,BCC
# ...                                   ...              ...       ...
# 4647                            Not found        Not found     FCC,σ
# 4648   Co19.6Cr19.6Fe19.6Mn19.6Ni19.6N2.1        Not found  FCC,Cr2N
# 4649                            Not found        Not found       FCC
# 4650                            Not found        Not found       FCC
# 4651                            Not found        Not found       BCC
#
#              alloy_condition                            doi  \
# 0               Cold-Sprayed  10.1016/j.jallcom.2021.162309
# 1                        SPS   10.1016/j.matdes.2022.111554
# 2                        SPS   10.1016/j.matdes.2022.111554
# 3                        SPS   10.1016/j.matdes.2022.111554
# 4                    As-Cast  10.1016/j.actamat.2023.118806
# ...                      ...                            ...
# 4647                 As-Cast  10.1016/j.jallcom.2021.163217
# 4648                 As-Cast  10.1016/j.jallcom.2021.163217
# 4649                 As-cast   10.1016/j.mtcomm.2022.104686
# 4650  As-cast + solutionized   10.1016/j.mtcomm.2022.104686
# 4651                 As-cast   10.1016/j.mtcomm.2022.104686
#
#                                       confidence_scores   Paperid   0
# 0     {'name': 100, 'nominal_composition': 95, 'meas...   doi_632 NaN
# 1     {'name': 100, 'nominal_composition': 95, 'meas...  doi_1212 NaN
# 2     {'name': 100, 'nominal_composition': 95, 'meas...  doi_1212 NaN
# 3     {'name': 100, 'nominal_composition': 95, 'meas...  doi_1212 NaN
# 4     {'name': 100, 'nominal_composition': 100, 'mea...   doi_174 NaN
# ...                                                 ...       ...  ..
# 4647  {'name': 100, 'nominal_composition': 95, 'meas...   doi_648 NaN
# 4648  {'name': 100, 'nominal_composition': 95, 'meas...   doi_648 NaN
# 4649  {'name': 100, 'nominal_composition': 90, 'meas...  doi_1856 NaN
# 4650  {'name': 100, 'nominal_composition': 95, 'meas...  doi_1856 NaN
# 4651  {'name': 100, 'nominal_composition': 90, 'meas...  doi_1856 NaN
#
# [4652 rows x 10 columns]

# %%
combined_df = combined_df.sort_values(by='Paperid')

# %%
combined_df
# Out:
#                          name             nominal_composition  \
# 287        Ti0.25Ta1.75NbZrMo     Ti0.25Ta1.75Nb1.0Zr1.0Mo1.0
# 284                TiTaNbZrMo       Ti1.0Ta1.0Nb1.0Zr1.0Mo1.0
# 285        Ti0.75Ta1.25NbZrMo     Ti0.75Ta1.25Nb1.0Zr1.0Mo1.0
# 286          Ti0.5Ta1.5NbZrMo       Ti0.5Ta1.5Nb1.0Zr1.0Mo1.0
# 2685                       V5          Nb25.0Ti35.0V5.0Zr35.0
# ...                       ...                             ...
# 2710  Al0.5Ti3Zr0.5Nb0.5Mo0.2       Al0.5Ti3.0Zr0.5Nb0.5Mo0.2
# 4076                   HNTVA0        Hf1.0Nb1.0Ti1.0V1.0Al0.0
# 4075                  HNTVA10        Hf1.0Nb1.0Ti1.0V1.0Al1.0
# 4077                   HNTVA5        Hf1.0Nb1.0Ti1.0V1.0Al0.5
# 1467     Al18Co30Cr11Fe11Ni30  Al18.0Co30.0Cr11.0Fe11.0Ni30.0
#
#             measured_composition lattice_constant     phases alloy_condition  \
# 287                    Not found            3.315  BCC1,BCC2         As-Cast
# 284                    Not found            3.285  BCC1,BCC2         As-Cast
# 285                    Not found             3.29  BCC1,BCC2         As-Cast
# 286                    Not found             3.31  BCC1,BCC2         As-Cast
# 2685  Nb25.07Ti34.32V4.95Zr35.67             3.35        BCC         As-Cast
# ...                          ...              ...        ...             ...
# 2710                   Not found            3.293        BCC         As-Cast
# 4076                   Not found        Not found        BCC        Annealed
# 4075                   Not found              3.3        BCC        Annealed
# 4077                   Not found        Not found        BCC        Annealed
# 1467                   Not found        Not found    FCC,BCC         As-Cast
#
#                                 doi  \
# 287   10.1016/j.jallcom.2024.174408
# 284   10.1016/j.jallcom.2024.174408
# 285   10.1016/j.jallcom.2024.174408
# 286   10.1016/j.jallcom.2024.174408
# 2685   10.1016/j.matdes.2024.113260
# ...                             ...
# 2710     10.1038/s41467-025-58211-9
# 4076     10.1038/s41586-023-06894-9
# 4075     10.1038/s41586-023-06894-9
# 4077     10.1038/s41586-023-06894-9
# 1467     10.1038/s43246-024-00450-2
#
#                                       confidence_scores  \
# 287   {'name': 100, 'nominal_composition': 95, 'meas...
# 284   {'name': 100, 'nominal_composition': 95, 'meas...
# 285   {'name': 100, 'nominal_composition': 95, 'meas...
# 286   {'name': 100, 'nominal_composition': 95, 'meas...
# 2685  {'name': 100, 'nominal_composition': 100, 'mea...
# ...                                                 ...
# 2710  {'name': 100, 'nominal_composition': 100, 'mea...
# 4076  {'name': 100, 'nominal_composition': 90, 'meas...
# 4075  {'name': 100, 'nominal_composition': 90, 'meas...
# 4077  {'name': 100, 'nominal_composition': 90, 'meas...
# 1467  {'name': 100, 'nominal_composition': 100, 'mea...
#
#                             Paperid   0
# 287                            1-s2 NaN
# 284                            1-s2 NaN
# 285                            1-s2 NaN
# 286                            1-s2 NaN
# 2685  1-s2-0-S026412752400635X-main NaN
# ...                             ...  ..
# 2710             s41467-025-58211-9 NaN
# 4076             s41586-023-06894-9 NaN
# 4075             s41586-023-06894-9 NaN
# 4077             s41586-023-06894-9 NaN
# 1467             s43246-024-00450-2 NaN
#
# [4652 rows x 10 columns]

# %%
combined_df.to_csv("Data_extracted.csv",index=False)
